# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaniii2021/DSAL/blob/main/lab_5_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Modified from: https://github.com/codebasics/data-structures-algorithms-python/blob/master/data_structures/7_Tree/7_tree.py

class Node:
    def __init__(self, data):
        self.parent = None
        self.data = data
        self.children = []
        self.layer = 0



    # def print_node_data(self):
    #     print(self.data)

    def print_tree(self):
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__" if self.parent else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree()

    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent

        return level

    def add_child(self, child):
        child.parent = self
        self.children.append(child)
        child.layer = self.layer + 1


#
# node1 = Node("1")
# node1.add_child(Node("2"))
# node1.add_child(Node("3"))
# #node1.add_child(Node("4"))
# node1.children.append(Node("4"))
# node1.print_tree()
#
# print(type(node1.children[0]))
# node1.children[0].add_child(Node("20"))
# node1.print_tree()
#
#
# rootNode = Node("Emilia + Roberto")
# rootNode.add_child(Node("Berta"))
# rootNode.add_child(Node("Beth"))
# rootNode.add_child(Node("Bobet"))
# # rootNode.print_tree() # Layer 0 + Layer 1
# #grandChildNode = Node("Miguel")
# #rootNode.children[0].add_child(grandChildNode)
# rootNode.children[0].add_child(Node("Miguel"))  # Line 65 + 66
# # rootNode.print_tree()
# rootNode.children[0].add_child(Node("Milo"))
# rootNode.children[0].add_child(Node("Miko"))
# rootNode.children[1].add_child(Node("Ben"))
# rootNode.print_tree()
# rootNode.children[0].data = "Berta + Lino"
# rootNode.print_tree()

foodNode = Node("food")
print(foodNode.data)
print(foodNode.parent)
print(foodNode.layer)
print(foodNode.children)
foodNode.add_child(Node("go"))
print(foodNode.children)
print(foodNode.children[0].data)
print(foodNode.children[0].parent)
print(foodNode.children[0].layer)
print(foodNode.children[0].children)
foodNode.add_child(Node("grow"))
print(foodNode.children)
print(foodNode.children[1].data)
print(foodNode.children[1].parent)
print(foodNode.children[1].layer)
print(foodNode.children[1].children)

foodNode.add_child(Node("glow"))
print(foodNode.children)
print(foodNode.children[2].data)
print(foodNode.children[2].parent)
print(foodNode.children[2].layer)
print(foodNode.children[2].children)

foodNode.children[0].add_child(Node("rice"))
print(foodNode.children[0].children[0].data)
print(foodNode.children[0].children[0].parent)
print(foodNode.children[0].children[0].layer)
print(foodNode.children[0].children[0].children)

foodNode.print_tree()
print("------------------------")
# foodNode.children[0].print_tree()
# foodNode.children.pop(0)
# print("------------------------")
# foodNode.print_tree()
foodNode.children[0].children[0].add_child(Node("nfa rice"))
foodNode.print_tree()
# rice = Node("rice")
# go.add_child(rice)
# Out:
# food
# None
# 0
# []
# ...
# go
# ...
# 1
# []
# [<__main__.Node object at 0x7f7bf1790110>, <__main__.Node object at 0x7f7bf1790790>]
# grow
# ...
# 1
# []
# [<__main__.Node object at 0x7f7bf1790110>, <__main__.Node object at 0x7f7bf1790790>, <__main__.Node object at 0x7f7bf17907d0>]
# glow
# ...
# 1
# []
# rice
# ...
# 2
# []
# food
#    |__go
#       |__rice
#    |__grow
#    |__glow
# ------------------------
# food
#    |__go
#       |__rice
#          |__nfa rice
#    |__grow
#    |__glow

# %%
# Modified from: https://github.com/codebasics/data-structures-algorithms-python/blob/master/data_structures/7_Tree/7_tree.py

class TreeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
        self.parent = None

    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent

        return level

    def print_tree(self):
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__" if self.parent else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree()

    def add_child(self, child):
        child.parent = self
        self.children.append(child)




# def build_product_tree():
#     root = TreeNode("Electronics")
#
#     laptop = TreeNode("Laptop")
#     laptop.add_child(TreeNode("Mac"))
#     laptop.add_child(TreeNode("Surface"))
#     laptop.add_child(TreeNode("Thinkpad"))
#
#     cellphone = TreeNode("Cell Phone")
#     cellphone.add_child(TreeNode("iPhone"))
#     cellphone.add_child(TreeNode("Google Pixel"))
#     cellphone.add_child(TreeNode("Vivo"))
#
#     tv = TreeNode("TV")
#     tv.add_child(TreeNode("Samsung"))
#     tv.add_child(TreeNode("LG"))
#
#     root.add_child(laptop)
#     root.add_child(cellphone)
#     root.add_child(tv)
#
#     root.print_tree()


if __name__ == '__main__':

    print("3 nodes that are not connected to each other")
    node1 = TreeNode("1")
    node2 = TreeNode("2")
    node3 = TreeNode("3")
    node1.print_tree()
    node2.print_tree()
    node3.print_tree()

    print("1 node with 2 child nodes")
    node1 = TreeNode("1")
    node1.add_child(TreeNode("2"))
    node1.add_child(TreeNode("3"))
    node1.print_tree()

    print("A sample tree data structure")

    z = TreeNode("Z")
    z.add_child(TreeNode("R"))
    # r = TreeNode("R")
    # r.add_child(TreeNode("S"))
    # s =TreeNode("S")
    # r.add_child(s)
    c = TreeNode("C")
    e = TreeNode("E")
    t = TreeNode("T")
    p = TreeNode("P")
    a = TreeNode("A")
    j = TreeNode("J")
    m = TreeNode("M")
    a.add_child(e)
    a.add_child(t)
    j.add_child(p)
    m.add_child(z)
    m.add_child(c)
    l = TreeNode("L")
    l.add_child(a)
    l.add_child(j)
    l.add_child(m)
    l.print_tree()

    print("The children of z are: ", m.print_tree())
# Out:
# 3 nodes that are not connected to each other
# 1
# 2
# 3
# 1 node with 2 child nodes
# 1
#    |__2
#    |__3
# A sample tree data structure
# L
#    |__A
#       |__E
#       |__T
#    |__J
#       |__P
#    |__M
#       |__Z
#          |__R
#       |__C
#    |__M
#       |__Z
#          |__R
#       |__C
# The children of z are:  None
